# %%
example_list=[0, 1, 2, 3, 4]

# %%
example_list[-1:-3]
# Out:
# []

# %%
def calc_disc(price):
    if price >=5000:
        disc=0.2
    else:
        disc=0.1
    return price*(1.0-disc)

# %%
calc_disc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 calc_disc()
#
# TypeError: calc_disc() missing 1 required positional argument: 'price'
